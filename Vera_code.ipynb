# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sn

# %%
df=pd.read_csv('Dataset.csv')
df
# Out:
#       Gender        Age    Height      Weight FHOW FAVC  FCVC  NCP       CAEC  \
# 0     Female  21.000000  1.620000   64.000000  yes   no   2.0  3.0  Sometimes
# 1     Female  21.000000  1.520000   56.000000  yes   no   3.0  3.0  Sometimes
# 2       Male  23.000000  1.800000   77.000000  yes   no   2.0  3.0  Sometimes
# 3       Male  27.000000  1.800000   87.000000   no   no   3.0  3.0  Sometimes
# 4       Male  22.000000  1.780000   89.800000   no   no   2.0  1.0  Sometimes
# ...      ...        ...       ...         ...  ...  ...   ...  ...        ...
# 2106  Female  20.976842  1.710730  131.408528  yes  yes   3.0  3.0  Sometimes
# 2107  Female  21.982942  1.748584  133.742943  yes  yes   3.0  3.0  Sometimes
# 2108  Female  22.524036  1.752206  133.689352  yes  yes   3.0  3.0  Sometimes
# 2109  Female  24.361936  1.739450  133.346641  yes  yes   3.0  3.0  Sometimes
# 2110  Female  23.664709  1.738836  133.472641  yes  yes   3.0  3.0  Sometimes
#
# ...

# %%
fig = plt.figure(figsize = (13, 7))
#Count the number of datapoints attributed with each weight category
counts = df["NObeyesdad"].value_counts()
plt.bar(counts.index, counts.values, color="green")
plt.xlabel("Weight Classification")
plt.ylabel("Number of Respondents")
plt.title("Number of Respondents per Weight Classification")
plt.savefig('count.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(6, 6))

# Define the color palette for each category
colors = {'Female': 'pink','Male': 'cyan'}

# Create the grouped bar chart
g = sn.catplot(x="NObeyesdad", hue="Gender", col="FAVC", kind="count", palette=colors, data=df)
g.set_xticklabels(rotation=30)
plt.savefig('barfav.png', dpi=300, bbox_inches='tight')
#plt.title("Number of Respondents per Weight Classification for people with high caloric food consumption")

plt.show()

# %%
plt.figure(figsize=(3,3))
colors = {'Female': 'pink', 'Male': 'cyan'}
g = sns.catplot(x="FAVC", hue="Gender", col="NObeyesdad", kind="count", palette=colors, data=df, height=6, aspect=1, col_wrap=3)
g.set_xticklabels(rotation=30)
plt.subplots_adjust(top=0.9)
g.set_titles("{col_name}")
plt.savefig('fav2.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(6, 6))
colors = {
    'Female': 'pink',  
    'Male': 'cyan'}
sn.barplot(x=df.NObeyesdad,y=df.FAF,hue=df.Gender,ci=None,palette=colors)
plt.xlabel('NObeyesdad')
plt.ylabel('Frequency for physical activity')
plt.xticks(rotation=45)
plt.title('Relationship between Frequency for physical activity and obesity level ')
plt.savefig('bar_chart.png', dpi=300, bbox_inches='tight')
plt.show()
